# %%
import pandas as pd
import altair as alt

# %%
# read parquet data with date info
crimes = pd.read_parquet('../data/crimes.parquet')

# %%
crimes
# Out:
#                ID Case Number                Date                   Block  \
# 0        10351578    HY542217 2015-12-10 08:00:00       019XX S MILLER ST
# 1        10351580    HY542156 2015-11-16 15:59:00       019XX W CERMAK RD
# 2        10351582    HY542092 2015-12-18 13:00:00         034XX W 77TH ST
# 3        10351583    HY542284 2015-12-18 17:50:00     040XX W HARRISON ST
# 4        10351584    HY542135 2015-12-18 16:55:00     071XX S BENNETT AVE
# ...           ...         ...                 ...                     ...
# 7643702  12830673    JF400391 2022-09-18 00:51:00  068XX S MARSHFIELD AVE
# 7643703  12832499    JF402441 2022-09-19 15:10:00    003XX W VAN BUREN ST
# 7643704  12835537    JF406097 2022-09-21 17:00:00     097XX S PARNELL AVE
# 7643705  12835278    JF405774 2022-09-21 22:27:00        012XX W 111TH ST
# 7643706  12829957    JF399377 2022-09-17 07:00:00      066XX S VERNON AVE
#
#          IUCR             Primary Type               Description  \
# 0        1130       DECEPTIVE PRACTICE  FRAUD OR CONFIDENCE GAME
# 1        1110       DECEPTIVE PRACTICE               BOGUS CHECK
# 2        0460                  BATTERY                    SIMPLE
# 3        2024                NARCOTICS       POSS: HEROIN(WHITE)
# 4        0486                  BATTERY   DOMESTIC BATTERY SIMPLE
# ...       ...                      ...                       ...
# 7643702  0261  CRIMINAL SEXUAL ASSAULT      AGGRAVATED - HANDGUN
# 7643703  0910      MOTOR VEHICLE THEFT                AUTOMOBILE
# 7643704  0910      MOTOR VEHICLE THEFT                AUTOMOBILE
# 7643705  1310          CRIMINAL DAMAGE               TO PROPERTY
# 7643706  0910      MOTOR VEHICLE THEFT                AUTOMOBILE
#
#              Location Description  Arrest  Domestic  ...  Ward  \
# 0                       RESIDENCE   False     False  ...  25.0
# 1               CURRENCY EXCHANGE   False     False  ...  25.0
# 2        SCHOOL, PUBLIC, BUILDING   False     False  ...  18.0
# 3          VEHICLE NON-COMMERCIAL    True     False  ...  24.0
# 4                       APARTMENT   False      True  ...   5.0
# ...                           ...     ...       ...  ...   ...
# 7643702                     ALLEY   False     False  ...  17.0
# 7643703                    STREET   False     False  ...  25.0
# 7643704                    STREET   False     False  ...  21.0
# 7643705               GAS STATION   False     False  ...  34.0
# 7643706                    STREET   False     False  ...  20.0
#
#          Community Area  FBI Code  X Coordinate Y Coordinate  Year  \
# 0                  31.0        11     1169771.0    1890901.0  2015
# 1                  31.0        11     1163681.0    1889417.0  2015
# 2                  70.0       08B     1154616.0    1853337.0  2015
# 3                  26.0        18     1149623.0    1897057.0  2015
# 4                  43.0       08B     1189943.0    1857970.0  2015
# ...                 ...       ...           ...          ...   ...
# 7643702            67.0        02           NaN          NaN  2022
# 7643703            32.0        07           NaN          NaN  2022
# 7643704            73.0        07           NaN          NaN  2022
# 7643705            75.0        14           NaN          NaN  2022
# 7643706            42.0        07           NaN          NaN  2022
#
#                  Updated On   Latitude  Longitude  \
# 0       2018-02-10 15:50:01  41.856134 -87.652335
# 1       2018-02-10 15:50:01  41.852192 -87.674730
# 2       2018-02-10 15:50:01  41.753370 -87.708963
# 3       2018-02-10 15:50:01  41.873441 -87.726128
# 4       2018-02-10 15:50:01  41.765306 -87.579355
# ...                     ...        ...        ...
# 7643702 2022-10-07 16:46:51        NaN        NaN
# 7643703 2022-10-07 16:46:51        NaN        NaN
# 7643704 2022-10-07 16:46:51        NaN        NaN
# 7643705 2022-10-07 16:46:51        NaN        NaN
# 7643706 2022-10-07 16:46:51        NaN        NaN
#
#                               Location
# 0        (41.856133986, -87.652334517)
# 1        (41.852192114, -87.674729636)
# 2        (41.753369537, -87.708962817)
# 3        (41.873441474, -87.726128458)
# 4        (41.765306435, -87.579354758)
# ...                                ...
# 7643702                           None
# 7643703                           None
# 7643704                           None
# 7643705                           None
# 7643706                           None
#
# [7643707 rows x 22 columns]

# %%
# get crime counts by primary type
crimes_by_type = crimes.groupby('Primary Type').size().to_frame(name='Total')
crimes_by_type = crimes_by_type.reset_index().sort_values(by=['Total'], ascending=False)
crimes_by_type
# Out:
#                          Primary Type    Total
# 34                              THEFT  1612023
# 2                             BATTERY  1401115
# 6                     CRIMINAL DAMAGE   871255
# 19                          NARCOTICS   744105
# 1                             ASSAULT   495960
# 26                      OTHER OFFENSE   475452
# 3                            BURGLARY   420155
# 18                MOTOR VEHICLE THEFT   357647
# 9                  DECEPTIVE PRACTICE   334363
# 31                            ROBBERY   287001
# 8                   CRIMINAL TRESPASS   211814
# 35                  WEAPONS VIOLATION   101961
# 27                       PROSTITUTION    69705
# 24         OFFENSE INVOLVING CHILDREN    54501
# 29             PUBLIC PEACE VIOLATION    51914
# 32                        SEX OFFENSE    29950
# 5                 CRIM SEXUAL ASSAULT    27706
# 14   INTERFERENCE WITH PUBLIC OFFICER    18121
# 17               LIQUOR LAW VIOLATION    14793
# 11                           GAMBLING    14616
# 0                               ARSON    13014
# 12                           HOMICIDE    12197
# 16                         KIDNAPPING     7153
# 7             CRIMINAL SEXUAL ASSAULT     5703
# 15                       INTIMIDATION     4524
# 33                           STALKING     4512
# 4   CONCEALED CARRY LICENSE VIOLATION      979
# 23                          OBSCENITY      786
# 28                   PUBLIC INDECENCY      192
# 21                       NON-CRIMINAL      178
# 25           OTHER NARCOTIC VIOLATION      145
# 13                  HUMAN TRAFFICKING       95
# 20                     NON - CRIMINAL       38
# 30                          RITUALISM       24
# 22   NON-CRIMINAL (SUBJECT SPECIFIED)        9
# 10                  DOMESTIC VIOLENCE        1

# %%
# create crimes by type bar chart
alt.Chart(crimes_by_type[0:20]).mark_bar().encode(
  x={'field': 'Total', 'type': 'quantitative', 'title': 'Reports'},
  y={'field': 'Primary Type', 'type': 'nominal', 'title': 'Crime', 'sort': '-x'},
  tooltip=[
    {'field': 'Primary Type', 'type': 'nominal', 'title': 'Crime Type'},
    {'field': 'Total', 'type': 'quantitative', 'title': 'Reports'}
  ],
  color=alt.value('crimson')
).properties(title='Chicago Crime Reports by Type - 2001-2022')
# Out:
# alt.Chart(...)

# %%
# set Date index for the time series plots
crimes.index = crimes['Date']
crimes
# Out:
#                            ID Case Number                Date  \
# Date
# 2015-12-10 08:00:00  10351578    HY542217 2015-12-10 08:00:00
# 2015-11-16 15:59:00  10351580    HY542156 2015-11-16 15:59:00
# 2015-12-18 13:00:00  10351582    HY542092 2015-12-18 13:00:00
# 2015-12-18 17:50:00  10351583    HY542284 2015-12-18 17:50:00
# 2015-12-18 16:55:00  10351584    HY542135 2015-12-18 16:55:00
# ...                       ...         ...                 ...
# 2022-09-18 00:51:00  12830673    JF400391 2022-09-18 00:51:00
# 2022-09-19 15:10:00  12832499    JF402441 2022-09-19 15:10:00
# 2022-09-21 17:00:00  12835537    JF406097 2022-09-21 17:00:00
# 2022-09-21 22:27:00  12835278    JF405774 2022-09-21 22:27:00
# 2022-09-17 07:00:00  12829957    JF399377 2022-09-17 07:00:00
#
#                                       Block  IUCR             Primary Type  \
# Date
# 2015-12-10 08:00:00       019XX S MILLER ST  1130       DECEPTIVE PRACTICE
# 2015-11-16 15:59:00       019XX W CERMAK RD  1110       DECEPTIVE PRACTICE
# 2015-12-18 13:00:00         034XX W 77TH ST  0460                  BATTERY
# 2015-12-18 17:50:00     040XX W HARRISON ST  2024                NARCOTICS
# 2015-12-18 16:55:00     071XX S BENNETT AVE  0486                  BATTERY
# ...                                     ...   ...                      ...
# 2022-09-18 00:51:00  068XX S MARSHFIELD AVE  0261  CRIMINAL SEXUAL ASSAULT
# 2022-09-19 15:10:00    003XX W VAN BUREN ST  0910      MOTOR VEHICLE THEFT
# 2022-09-21 17:00:00     097XX S PARNELL AVE  0910      MOTOR VEHICLE THEFT
# 2022-09-21 22:27:00        012XX W 111TH ST  1310          CRIMINAL DAMAGE
# 2022-09-17 07:00:00      066XX S VERNON AVE  0910      MOTOR VEHICLE THEFT
#
#                                   Description      Location Description  \
# Date
# 2015-12-10 08:00:00  FRAUD OR CONFIDENCE GAME                 RESIDENCE
# 2015-11-16 15:59:00               BOGUS CHECK         CURRENCY EXCHANGE
# 2015-12-18 13:00:00                    SIMPLE  SCHOOL, PUBLIC, BUILDING
# 2015-12-18 17:50:00       POSS: HEROIN(WHITE)    VEHICLE NON-COMMERCIAL
# 2015-12-18 16:55:00   DOMESTIC BATTERY SIMPLE                 APARTMENT
# ...                                       ...                       ...
# 2022-09-18 00:51:00      AGGRAVATED - HANDGUN                     ALLEY
# 2022-09-19 15:10:00                AUTOMOBILE                    STREET
# 2022-09-21 17:00:00                AUTOMOBILE                    STREET
# 2022-09-21 22:27:00               TO PROPERTY               GAS STATION
# 2022-09-17 07:00:00                AUTOMOBILE                    STREET
#
#                      Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# Date                                   ...
# 2015-12-10 08:00:00   False     False  ...  25.0            31.0        11
# 2015-11-16 15:59:00   False     False  ...  25.0            31.0        11
# 2015-12-18 13:00:00   False     False  ...  18.0            70.0       08B
# 2015-12-18 17:50:00    True     False  ...  24.0            26.0        18
# 2015-12-18 16:55:00   False      True  ...   5.0            43.0       08B
# ...                     ...       ...  ...   ...             ...       ...
# 2022-09-18 00:51:00   False     False  ...  17.0            67.0        02
# 2022-09-19 15:10:00   False     False  ...  25.0            32.0        07
# 2022-09-21 17:00:00   False     False  ...  21.0            73.0        07
# 2022-09-21 22:27:00   False     False  ...  34.0            75.0        14
# 2022-09-17 07:00:00   False     False  ...  20.0            42.0        07
#
#                      X Coordinate Y Coordinate  Year          Updated On  \
# Date
# 2015-12-10 08:00:00     1169771.0    1890901.0  2015 2018-02-10 15:50:01
# 2015-11-16 15:59:00     1163681.0    1889417.0  2015 2018-02-10 15:50:01
# 2015-12-18 13:00:00     1154616.0    1853337.0  2015 2018-02-10 15:50:01
# 2015-12-18 17:50:00     1149623.0    1897057.0  2015 2018-02-10 15:50:01
# 2015-12-18 16:55:00     1189943.0    1857970.0  2015 2018-02-10 15:50:01
# ...                           ...          ...   ...                 ...
# 2022-09-18 00:51:00           NaN          NaN  2022 2022-10-07 16:46:51
# 2022-09-19 15:10:00           NaN          NaN  2022 2022-10-07 16:46:51
# 2022-09-21 17:00:00           NaN          NaN  2022 2022-10-07 16:46:51
# 2022-09-21 22:27:00           NaN          NaN  2022 2022-10-07 16:46:51
# 2022-09-17 07:00:00           NaN          NaN  2022 2022-10-07 16:46:51
#
#                       Latitude  Longitude                       Location
# Date
# 2015-12-10 08:00:00  41.856134 -87.652335  (41.856133986, -87.652334517)
# 2015-11-16 15:59:00  41.852192 -87.674730  (41.852192114, -87.674729636)
# 2015-12-18 13:00:00  41.753370 -87.708963  (41.753369537, -87.708962817)
# 2015-12-18 17:50:00  41.873441 -87.726128  (41.873441474, -87.726128458)
# 2015-12-18 16:55:00  41.765306 -87.579355  (41.765306435, -87.579354758)
# ...                        ...        ...                            ...
# 2022-09-18 00:51:00        NaN        NaN                           None
# 2022-09-19 15:10:00        NaN        NaN                           None
# 2022-09-21 17:00:00        NaN        NaN                           None
# 2022-09-21 22:27:00        NaN        NaN                           None
# 2022-09-17 07:00:00        NaN        NaN                           None
#
# [7643707 rows x 22 columns]

# %%
# get crimes by type
crimes_by_type = crimes[['Primary Type']]

# create monthly crime report counts
monthly_reports = crimes_by_type.resample('M').count()
monthly_reports.columns = ['Reports'] # rename Primary Type column
monthly_reports = monthly_reports.reset_index()
monthly_reports
# Out:
#           Date  Reports
# 0   2001-01-31    38114
# 1   2001-02-28    33783
# 2   2001-03-31    40562
# 3   2001-04-30    40088
# 4   2001-05-31    41835
# ..         ...      ...
# 256 2022-05-31    19925
# 257 2022-06-30    20444
# 258 2022-07-31    21912
# 259 2022-08-31    21809
# 260 2022-09-30    21280
#
# [261 rows x 2 columns]

# %%
# plot monthly crime reports
alt.Chart(monthly_reports).mark_line().encode(
  x='Date:T',
  y='Reports:Q',
  color=alt.value('crimson')
).properties(title='Monthly Chicago Crime Reports - 2001-2022')
# Out:
# alt.Chart(...)

# %%
# get arrests
arrests = crimes[crimes['Arrest'] == True]['Arrest']

# sum arrests per month
monthly_arrests = arrests.resample('M').sum().to_frame(name='Arrests')
monthly_arrests = monthly_arrests.reset_index()
monthly_arrests
# Out:
#           Date  Arrests
# 0   2001-01-31    12239
# 1   2001-02-28    10964
# 2   2001-03-31    12491
# 3   2001-04-30    11870
# 4   2001-05-31    12059
# ..         ...      ...
# 256 2022-05-31     2727
# 257 2022-06-30     2397
# 258 2022-07-31     2245
# 259 2022-08-31     2247
# 260 2022-09-30     2075
#
# [261 rows x 2 columns]

# %%
# plot monthly arrests
alt.Chart(monthly_arrests).mark_line().encode(
  x='Date:T',
  y='Arrests:Q',
  color=alt.value('crimson')
).properties(title='Monthly Chicago Arrests - 2001-2022')
# Out:
# alt.Chart(...)

# %%
# get domestic crime reports
domestic_reports = crimes[crimes['Domestic'] == True]['Domestic']

# sum domestic crime reports per month
monthly_domestic_reports = domestic_reports.resample('M').sum().to_frame(name='Reports')
monthly_domestic_reports = monthly_domestic_reports.reset_index()
monthly_domestic_reports
# Out:
#           Date  Reports
# 0   2001-01-31     4720
# 1   2001-02-28     4242
# 2   2001-03-31     5080
# 3   2001-04-30     5149
# 4   2001-05-31     5417
# ..         ...      ...
# 256 2022-05-31     3922
# 257 2022-06-30     3940
# 258 2022-07-31     3887
# 259 2022-08-31     3840
# 260 2022-09-30     3457
#
# [261 rows x 2 columns]

# %%
# plot monthly domestic crime reports
alt.Chart(monthly_domestic_reports).mark_line().encode(
  x='Date:T',
  y='Reports:Q',
).properties(title='Monthly Domestic Chicago Crime Reports - 2001-2022')
# Out:
# alt.Chart(...)

# %%
# get crime location counts
crime_locations = crimes.groupby('Location Description').size()
crime_locations = crime_locations.sort_values(
    ascending=False).rename('Reports').reset_index()

# print crime location stats
print(crime_locations.head(10))
print("...\nTotal Locations: {:,}".format(crime_locations.size))
# Out:
#              Location Description  Reports
# 0                          STREET  1984400
# 1                       RESIDENCE  1288019
# 2                       APARTMENT   853137
# 3                        SIDEWALK   722889
# 4                           OTHER   270046
# 5  PARKING LOT/GARAGE(NON.RESID.)   203000
# 6                           ALLEY   169859
# 7        SCHOOL, PUBLIC, BUILDING   146392
# 8              SMALL RETAIL STORE   143299
# 9                RESIDENCE-GARAGE   135544
# ...
# Total Locations: 430

# %%
# plot top 20 crime locations
alt.Chart(crime_locations[0:20]).mark_bar().encode(
    x={'field': 'Reports', 'type': 'quantitative'},
    y={'field': 'Location Description', 'type': 'nominal', 'sort': '-x'},
    tooltip=['Location Description', 'Reports'],
    color=alt.value('crimson')
).properties(title='Top 20 Chicago Crime Locations - 2001-2022')
# Out:
# alt.Chart(...)

# %%
# load Chicago community areas with pandas
# for plotting crime by Chicago sides and community areas
community_areas = pd.read_csv('../data/chicago-community-areas.csv')
community_areas.head()

# get community crime stats
community_areas['Reports'] = crimes.groupby(
    'Community Area').size().rename('Reports')
community_crime = community_areas.sort_values(
    by='Reports', ascending=False).dropna()

# print community crime stats
print(community_crime.head(10))
print("...\nTotal Communities: {:,}".format(community_crime.Reports.count()))
# Out:
#     CommunityArea    CommunityName                Side  Reports
# 25             25           Austin           West Side   441438
# 8               8  Near North Side             Central   246938
# 43             43      South Shore          South Side   231521
# 23             23    Humboldt Park           West Side   220210
# 28             28   Near West Side           West Side   211301
# 24             24        West Town           West Side   205859
# 29             29   North Lawndale           West Side   205808
# 67             67   West Englewood      Southwest Side   202499
# 71             71   Auburn Gresham  Far Southwest Side   199438
# 49             49         Roseland  Far Southeast Side   187192
# ...
# Total Communities: 77

# %%
# drop unused columns and reindex
community_crime = community_crime.drop(
    ['CommunityArea', 'Side'], axis=1)  # denotes column
community_crime.head(10)
# Out:
#       CommunityName  Reports
# 25           Austin   441438
# 8   Near North Side   246938
# 43      South Shore   231521
# 23    Humboldt Park   220210
# 28   Near West Side   211301
# 24        West Town   205859
# 29   North Lawndale   205808
# 67   West Englewood   202499
# 71   Auburn Gresham   199438
# 49         Roseland   187192

# %%
# plot 20 high crime communities
alt.Chart(community_crime[0:20]).mark_bar().encode(
  x={'field': 'Reports', 'type': 'quantitative'},
  y={'field': 'CommunityName', 'type': 'nominal', 'title': 'Community', 'sort': '-x'},
  tooltip=['CommunityName', 'Reports'],
  color=alt.value('crimson')
).properties(title='High Crime Chicago Communities - 2001-2022')
# Out:
# alt.Chart(...)

# %%
# plot 20 low crime communities
alt.Chart(community_crime.tail(20)).mark_bar().encode(
  x={'field': 'Reports', 'type': 'quantitative'},
  y={'field': 'CommunityName', 'type': 'nominal', 'title': 'Community', 'sort': 'x'},
  tooltip=['CommunityName', 'Reports']
).properties(title='Low Crime Chicago Communities - 2001-2022')
# Out:
# alt.Chart(...)

# %%
# group crime totals by Chicago sides
crimes_by_side = community_areas.groupby('Side').sum()\
    .drop('CommunityArea', axis=1)  # denotes column
crimes_by_side.sort_values(by='Reports', ascending=False)
crimes_by_side.reset_index()
# Out:
#                  Side  Reports
# 0             Central   474346
# 1      Far North Side   628196
# 2  Far Southeast Side   827899
# 3  Far Southwest Side   444103
# 4          North Side   503479
# 5      Northwest Side   399135
# 6          South Side   965119
# 7      Southwest Side  1051006
# 8           West Side  1736870

# %%
# get narcotics crimes
narcotics = crimes[crimes['Primary Type'] == 'NARCOTICS']
#print(narcotics.head())

# get narcotics crime description counts
narcotics_crimes = narcotics[['Primary Type', 'Description']]\
    .groupby('Description').count()\
    .sort_values(by='Primary Type', ascending=False)
narcotics_crimes.columns = ['Reports']  # rename Primary Type column
narcotics_crimes = narcotics_crimes.reset_index()

print(narcotics_crimes.head(10))
print('...')
print('Total Narcotics Crime Descriptions: {}'.format(len(narcotics_crimes)))
# Out:
#                       Description  Reports
# 0    POSS: CANNABIS 30GMS OR LESS   278139
# 1                     POSS: CRACK   121112
# 2             POSS: HEROIN(WHITE)    95786
# 3  SOLICIT NARCOTICS ON PUBLICWAY    27854
# 4    MANU/DELIVER: HEROIN (WHITE)    26446
# 5                   POSS: COCAINE    25470
# 6              MANU/DELIVER:CRACK    24949
# 7    ATTEMPT POSSESSION NARCOTICS    21366
# 8         FOUND SUSPECT NARCOTICS    19502
# 9  POSS: CANNABIS MORE THAN 30GMS    19092
# ...
# Total Narcotics Crime Descriptions: 80

# %%
# plot top 20 narcotics crime reports by description
alt.Chart(narcotics_crimes[0:20]).mark_bar().encode(
    x={'field': 'Reports', 'type': 'quantitative'},
    y={'field': 'Description', 'type': 'nominal', 'sort': '-x'},
    tooltip=['Description', 'Reports'],
    color=alt.value('crimson')
).properties(title='Top 20 Chicago Narcotics Crime Reports - 2001-2022')
# Out:
# alt.Chart(...)

# %%
# get other offenses crimes
other_offenses = crimes[crimes['Primary Type'] == 'OTHER OFFENSE']
#print(other_offenses.head())

# get other offense crime description counts
other_offense_crimes = other_offenses[['Primary Type', 'Description']]\
    .groupby('Description').count()\
    .sort_values(by='Primary Type', ascending=False)
other_offense_crimes.columns = ['Reports']  # rename Primary Type column
other_offense_crimes = other_offense_crimes.reset_index()

print(other_offense_crimes.head(10))
print('...')
print('Total Other Offense Crime Descriptions: {}'.format(len(other_offense_crimes)))
# Out:
#                       Description  Reports
# 0                TELEPHONE THREAT   148121
# 1         HARASSMENT BY TELEPHONE   109798
# 2           OTHER VEHICLE OFFENSE    40624
# 3     VIOLATE ORDER OF PROTECTION    39829
# 4  HARASSMENT BY ELECTRONIC MEANS    33313
# 5        FALSE/STOLEN/ALTERED TRP    21866
# 6  OTHER CRIME INVOLVING PROPERTY    12499
# 7      OTHER CRIME AGAINST PERSON     8657
# 8       VEHICLE TITLE/REG OFFENSE     8504
# 9               LICENSE VIOLATION     8366
# ...
# Total Other Offense Crime Descriptions: 63

# %%
# plot top 20 other offense crime reports by description
alt.Chart(other_offense_crimes[0:20]).mark_bar().encode(
  x={'field': 'Reports', 'type': 'quantitative'},
  y={'field': 'Description', 'type': 'nominal', 'sort': '-x'},
  tooltip=['Description', 'Reports'],
  color=alt.value('crimson')
).properties(title='Top 20 Other Offense Chicago Crime Reports - 2001-2022')
# Out:
# alt.Chart(...)
