# %%
import polars as pl

# %%
arrests = (
    pl.scan_csv("../data/crimes.csv")
    .filter(pl.col("Arrest") )
)

arrests_df = arrests.collect()
arrests_df
# Out:
# shape: (2017993, 22)
# ┌───────────┬───────────┬───────────┬───────────┬─────┬──────────┬───────────┬─────────┬───────────┐
# │ ID        ┆ Case      ┆ Date      ┆ Block     ┆ ... ┆ Updated  ┆ Latitude  ┆ Longitu ┆ Location  │
# │ ---       ┆ Number    ┆ ---       ┆ ---       ┆     ┆ On       ┆ ---       ┆ de      ┆ ---       │
# │ i64       ┆ ---       ┆ str       ┆ str       ┆     ┆ ---      ┆ f64       ┆ ---     ┆ str       │
# │           ┆ str       ┆           ┆           ┆     ┆ str      ┆           ┆ f64     ┆           │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═════╪══════════╪═══════════╪═════════╪═══════════╡
# │ 10224740  ┆ HY411595  ┆ 09/05/201 ┆ 035XX W   ┆ ... ┆ 02/10/20 ┆ 41.937406 ┆ -87.716 ┆ (41.93740 │
# │           ┆           ┆ 5         ┆ BARRY AVE ┆     ┆ 18       ┆           ┆ 65      ┆ 5765, -87 │
# │           ┆           ┆ 12:45:00  ┆           ┆     ┆ 03:50:01 ┆           ┆         ┆ .71664968 │
# ...
