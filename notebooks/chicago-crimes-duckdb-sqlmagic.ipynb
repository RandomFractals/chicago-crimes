# %%
import sys
# !{sys.executable} -m pip install duckdb notebook pandas ipython-sql SQLAlchemy duckdb-engine

# %%
import duckdb
import pandas as pd
import sqlalchemy

# Import ipython-sql Jupyter extension to create SQL cells
# %load_ext sql

# %%
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %%
# %sql duckdb:///:memory:

# %%
# %%sql
#
# create table crimes as
#     select * from read_csv_auto('../data/crimes.csv');
# Out:
#      Count
# 0  7643707

# %%
# %%sql
#
# describe crimes;
# Out:
#              column_name column_type null   key default extra
# 0                     ID     INTEGER  YES  None    None  None
# 1            Case Number     VARCHAR  YES  None    None  None
# 2                   Date   TIMESTAMP  YES  None    None  None
# 3                  Block     VARCHAR  YES  None    None  None
# 4                   IUCR     VARCHAR  YES  None    None  None
# 5           Primary Type     VARCHAR  YES  None    None  None
# 6            Description     VARCHAR  YES  None    None  None
# 7   Location Description     VARCHAR  YES  None    None  None
# 8                 Arrest     BOOLEAN  YES  None    None  None
# 9               Domestic     BOOLEAN  YES  None    None  None
# 10                  Beat     INTEGER  YES  None    None  None
# 11              District     INTEGER  YES  None    None  None
# 12                  Ward     INTEGER  YES  None    None  None
# 13        Community Area     INTEGER  YES  None    None  None
# 14              FBI Code     VARCHAR  YES  None    None  None
# 15          X Coordinate     INTEGER  YES  None    None  None
# 16          Y Coordinate     INTEGER  YES  None    None  None
# 17                  Year     INTEGER  YES  None    None  None
# 18            Updated On   TIMESTAMP  YES  None    None  None
# 19              Latitude      DOUBLE  YES  None    None  None
# 20             Longitude      DOUBLE  YES  None    None  None
# 21              Location     VARCHAR  YES  None    None  None
