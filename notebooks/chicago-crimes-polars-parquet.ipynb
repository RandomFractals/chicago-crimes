# %%
import polars as pl

# %%
crimes = pl.read_parquet('../data/crimes.parquet')
crimes
# Out:
# shape: (7643707, 22)
# ┌──────────┬───────────┬────────────┬───────────┬─────┬──────────┬───────────┬─────────┬───────────┐
# │ ID       ┆ Case      ┆ Date       ┆ Block     ┆ ... ┆ Updated  ┆ Latitude  ┆ Longitu ┆ Location  │
# │ ---      ┆ Number    ┆ ---        ┆ ---       ┆     ┆ On       ┆ ---       ┆ de      ┆ ---       │
# │ i32      ┆ ---       ┆ datetime[μ ┆ str       ┆     ┆ ---      ┆ f64       ┆ ---     ┆ str       │
# │          ┆ str       ┆ s]         ┆           ┆     ┆ datetime ┆           ┆ f64     ┆           │
# │          ┆           ┆            ┆           ┆     ┆ [μs]     ┆           ┆         ┆           │
# ╞══════════╪═══════════╪════════════╪═══════════╪═════╪══════════╪═══════════╪═════════╪═══════════╡
# │ 10351578 ┆ HY542217  ┆ 2015-12-10 ┆ 019XX S   ┆ ... ┆ 2018-02- ┆ 41.856134 ┆ -87.652 ┆ (41.85613 │
# │          ┆           ┆ 08:00:00   ┆ MILLER ST ┆     ┆ 10       ┆           ┆ 335     ┆ 3986, -87 │
# ...
