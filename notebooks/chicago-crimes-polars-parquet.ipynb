# %%
import polars as pl

# %%
crimes = pl.read_parquet('../data/crimes.parquet')
crimes
# Out:
# shape: (7643707, 22)
# ┌───────────┬───────────┬───────────┬───────────┬─────┬──────────┬───────────┬─────────┬───────────┐
# │ ID        ┆ Case      ┆ Date      ┆ Block     ┆ ... ┆ Updated  ┆ Latitude  ┆ Longitu ┆ Location  │
# │ ---       ┆ Number    ┆ ---       ┆ ---       ┆     ┆ On       ┆ ---       ┆ de      ┆ ---       │
# │ i64       ┆ ---       ┆ str       ┆ str       ┆     ┆ ---      ┆ f64       ┆ ---     ┆ str       │
# │           ┆ str       ┆           ┆           ┆     ┆ str      ┆           ┆ f64     ┆           │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═════╪══════════╪═══════════╪═════════╪═══════════╡
# │ 10224738  ┆ HY411648  ┆ 09/05/201 ┆ 043XX S   ┆ ... ┆ 02/10/20 ┆ 41.815117 ┆ -87.67  ┆ (41.81511 │
# │           ┆           ┆ 5         ┆ WOOD ST   ┆     ┆ 18       ┆           ┆         ┆ 7282, -87 │
# │           ┆           ┆ 01:30:00  ┆           ┆     ┆ 03:50:01 ┆           ┆         ┆ .66999956 │
# ...
